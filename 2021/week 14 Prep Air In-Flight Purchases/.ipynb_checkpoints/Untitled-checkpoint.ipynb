# %%
import pandas as pd
import numpy as np
import datetime

# %%
df_seats = pd.read_excel('Week 14 - Input.xlsx', sheet_name='SeatList').melt(id_vars='Row', value_name='Seat', var_name='Letter')
df_seats['Position'] = np.where(df_seats['Letter'].isin(['A','F']), 'Window', np.where(df_seats['Letter'].isin(['B','E']), 'Aisle', 'Middle'))
df_seats
# Out:
#      Row Letter  Seat Position
# 0      1      A     1   Window
# 1      2      A     7   Window
# 2      3      A    13   Window
# 3      4      A    19   Window
# 4      5      A    25   Window
# ..   ...    ...   ...      ...
# 115   16      F    96   Window
# 116   17      F   102   Window
# 117   18      F   108   Window
# 118   19      F   114   Window
# 119   20      F   120   Window
#
# [120 rows x 4 columns]

# %%
df_flights = pd.read_excel('Week 14 - Input.xlsx', sheet_name='FlightDetails')
df_flights[['Flight ID', 'From', 'To', 'Date', 'Time']] = df_flights['[FlightID|DepAir|ArrAir|DepDate|DepTime]'].str.strip('[]').str.split('|', expand=True)
df_flights['DateTime'] = pd.to_datetime(df_flights['Date'] + ' ' + df_flights['Time'], format='%Y-%m-%d %H:%M:%S')
df_flights['Time of day'] =  np.where(df_flights['DateTime'].dt.time < datetime.time(12,0,0), 'Morning',
                                  np.where(df_flights['DateTime'].dt.time <= datetime.time(18,0,0), 'Afternoon', 'Evening'))
df_flights.rename(columns={'Flight ID':'Flight'}, inplace=True)
df_flights['Flight'] = df_flights['Flight'].astype('int')
df_flights
# Out:
#   [FlightID|DepAir|ArrAir|DepDate|DepTime]  Flight From   To        Date  \
# 0          [1|LHR|SEA|2020-10-08|14:53:00]       1  LHR  SEA  2020-10-08
# 1          [2|MTY|JFK|2020-12-03|06:51:00]       2  MTY  JFK  2020-12-03
# 2          [3|SEA|BOS|2020-11-21|20:45:00]       3  SEA  BOS  2020-11-21
# 3          [4|LHR|BOS|2020-10-31|21:01:00]       4  LHR  BOS  2020-10-31
# 4          [5|MTY|CAI|2020-12-07|09:33:00]       5  MTY  CAI  2020-12-07
# 5          [6|JFK|LHR|2020-11-10|05:05:00]       6  JFK  LHR  2020-11-10
# 6          [7|TPE|LHR|2020-12-01|14:22:00]       7  TPE  LHR  2020-12-01
# 7          [8|BOS|SEA|2020-12-26|16:45:00]       8  BOS  SEA  2020-12-26
# 8          [9|JFK|LHR|2020-10-23|19:06:00]       9  JFK  LHR  2020-10-23
# 9         [10|CAI|LHR|2020-12-22|10:54:00]      10  CAI  LHR  2020-12-22
#
#        Time            DateTime Time of day
# 0  14:53:00 2020-10-08 14:53:00   Afternoon
# 1  06:51:00 2020-12-03 06:51:00     Morning
# 2  20:45:00 2020-11-21 20:45:00     Evening
# 3  21:01:00 2020-10-31 21:01:00     Evening
# 4  09:33:00 2020-12-07 09:33:00     Morning
# 5  05:05:00 2020-11-10 05:05:00     Morning
# 6  14:22:00 2020-12-01 14:22:00   Afternoon
# 7  16:45:00 2020-12-26 16:45:00   Afternoon
# 8  19:06:00 2020-10-23 19:06:00     Evening
# 9  10:54:00 2020-12-22 10:54:00     Morning

# %%
df_flight_classes = pd.read_excel('Week 14 - Input.xlsx', sheet_name='PlaneDetails')
df_flight_classes['last business row'] = df_flight_classes['Business Class'].str.extract('.*\-(.*)').astype('int')
df_flight_classes.rename(columns={'FlightNo.':'Flight'}, inplace=True)
df_flight_classes
# Out:
#    Flight Business Class  last business row
# 0       1            1-5                  5
# 1       2            1-8                  8
# 2       3           1-10                 10
# 3       4            1-5                  5
# 4       5            1-5                  5
# 5       6            1-5                  5
# 6       7            1-2                  2
# 7       8            1-3                  3
# 8       9            1-5                  5
# 9      10            1-5                  5

# %%
df_passengers = pd.read_excel('Week 14 - Input.xlsx', sheet_name='Passenger List')
df_passengers.rename(columns=lambda x : x.replace('_',' ').title(), inplace=True)
df_passengers.rename(columns={'Flight Number':'Flight', 'Passenger Number':'Seat'}, inplace=True)
df_passengers.dropna(axis=1,inplace=True)
df_passengers
# Out:
#     First Name  Last Name  Seat  Flight  Purchase Amount
# 0     Jerrylee       Rein     1       1            48.29
# 1     Forester   Iashvili     2       1             0.00
# 2        Shaun   Sherwill     3       1             0.00
# 3       Werner     Basile     4       1            58.21
# 4      Kerwinn    Skillen     5       1            41.96
# ..         ...        ...   ...     ...              ...
# 995       Skye  McLaverty   106      10            10.46
# 996    Margaux     Rymour   107      10             0.00
# 997      Corny    Vaszoly   108      10            44.60
# 998   Vittorio  Rushbrook   109      10             0.00
# 999     Murial       Nani   110      10            17.70
#
# [1000 rows x 5 columns]

# %%
df_output = pd.merge(df_passengers, df_seats, on='Seat').merge(df_flights, on='Flight').merge(df_flight_classes, on='Flight')
df_output['Class'] = np.where(df_output['Row'] <= df_output['last business row'], 'Business', 'Economy')
df_output
# Out:
#     First Name  Last Name  Seat  Flight  Purchase Amount  Row Letter Position  \
# 0     Jerrylee       Rein     1       1            48.29    1      A   Window
# 1     Forester   Iashvili     2       1             0.00    1      B    Aisle
# 2        Shaun   Sherwill     3       1             0.00    1      C   Middle
# 3       Werner     Basile     4       1            58.21    1      D   Middle
# 4      Kerwinn    Skillen     5       1            41.96    1      E    Aisle
# ..         ...        ...   ...     ...              ...  ...    ...      ...
# 995       Skye  McLaverty   106      10            10.46   18      D   Middle
# 996    Margaux     Rymour   107      10             0.00   18      E    Aisle
# 997      Corny    Vaszoly   108      10            44.60   18      F   Window
# 998   Vittorio  Rushbrook   109      10             0.00   19      A   Window
# 999     Murial       Nani   110      10            17.70   19      B    Aisle
#
#     [FlightID|DepAir|ArrAir|DepDate|DepTime] From   To        Date      Time  \
# 0            [1|LHR|SEA|2020-10-08|14:53:00]  LHR  SEA  2020-10-08  14:53:00
# 1            [1|LHR|SEA|2020-10-08|14:53:00]  LHR  SEA  2020-10-08  14:53:00
# 2            [1|LHR|SEA|2020-10-08|14:53:00]  LHR  SEA  2020-10-08  14:53:00
# 3            [1|LHR|SEA|2020-10-08|14:53:00]  LHR  SEA  2020-10-08  14:53:00
# 4            [1|LHR|SEA|2020-10-08|14:53:00]  LHR  SEA  2020-10-08  14:53:00
# ..                                       ...  ...  ...         ...       ...
# 995         [10|CAI|LHR|2020-12-22|10:54:00]  CAI  LHR  2020-12-22  10:54:00
# 996         [10|CAI|LHR|2020-12-22|10:54:00]  CAI  LHR  2020-12-22  10:54:00
# 997         [10|CAI|LHR|2020-12-22|10:54:00]  CAI  LHR  2020-12-22  10:54:00
# 998         [10|CAI|LHR|2020-12-22|10:54:00]  CAI  LHR  2020-12-22  10:54:00
# 999         [10|CAI|LHR|2020-12-22|10:54:00]  CAI  LHR  2020-12-22  10:54:00
#
#                DateTime Time of day Business Class  last business row  \
# 0   2020-10-08 14:53:00   Afternoon            1-5                  5
# 1   2020-10-08 14:53:00   Afternoon            1-5                  5
# 2   2020-10-08 14:53:00   Afternoon            1-5                  5
# 3   2020-10-08 14:53:00   Afternoon            1-5                  5
# 4   2020-10-08 14:53:00   Afternoon            1-5                  5
# ..                  ...         ...            ...                ...
# 995 2020-12-22 10:54:00     Morning            1-5                  5
# 996 2020-12-22 10:54:00     Morning            1-5                  5
# 997 2020-12-22 10:54:00     Morning            1-5                  5
# 998 2020-12-22 10:54:00     Morning            1-5                  5
# 999 2020-12-22 10:54:00     Morning            1-5                  5
#
#         Class
# 0    Business
# 1    Business
# 2    Business
# 3    Business
# 4    Business
# ..        ...
# 995   Economy
# 996   Economy
# 997   Economy
# 998   Economy
# 999   Economy
#
# [1000 rows x 18 columns]

# %%
df_avg_per_time = df_output.where(df_output['Class']!='Business').groupby(['Flight', 'Time of day'],as_index=False)['Purchase Amount'].sum().groupby('Time of day')['Purchase Amount'].mean()
df_avg_per_time
# Out:
# Time of day
# Afternoon    1959.096667
# Evening      1185.263333
# Morning      1478.312500
# Name: Purchase Amount, dtype: float64

# %%
df_seat_tot = df_output.where(df_output['Class']!='Business').groupby('Position')['Purchase Amount'].sum()
df_seat_tot
# Out:
# Position
# Aisle     4797.72
# Middle    4888.19
# Window    5660.42
# Name: Purchase Amount, dtype: float64

# %%
df_tot_per_class = df_output.groupby('Class')['Purchase Amount'].sum()
df_tot_per_class
# Out:
# Class
# Business     7207.69
# Economy     15346.33
# Name: Purchase Amount, dtype: float64
